# %%
from pandas.io.json import json_normalize  
import pandas as pd  
import json  
import time  
import numpy as np
from selenium import webdriver
#from twilio.rest import Client
from time import sleep
from selenium.webdriver.common.keys import Keys
from urllib.parse import quote

# %%
#driver = webdriver.Firefox(executable_path = '/root/.jupyter/geckodriver')
driver = webdriver.PhantomJS()
# Out:
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
wp='1'
_ksTS='1515549364328_142'
callback='jsonp143'
stype='1'
st_trust='1'
q='代购'
from urllib.parse import quote
q = quote(q.encode("gbk"))
#q = quote(q, encoding='gbk',safe='/:?=')
ist='1'
#start_urls='https://s.2.taobao.com/list/waterfall/waterfall.htm?wp='+wp+'&_ksTS='+_ksTS+'&callback='+callback+'&stype='+stype+'&st_trust='+st_trust+'&q='+q+'&ist='+ist
_input_charset = 'utf8'
divisionId = '220500'
nq = '代购'
start_urls = "https://s.2.taobao.com/list/list.htm?spm=2007.1000337.2.1.63816edecy4Aam&catid=50448012&st_price=0&q=%B4%FA%B9%BA&ist=2"
print(start_urls)
driver.get(start_urls)

print(driver)
# Out:
# https://s.2.taobao.com/list/list.htm?spm=2007.1000337.2.1.63816edecy4Aam&catid=50448012&st_price=0&q=%B4%FA%B9%BA&ist=2
# <selenium.webdriver.phantomjs.webdriver.WebDriver (session="dc7963e0-ff7c-11e7-8a6f-4bc6dd3bc653")>

# %%
driver.save_screenshot('csdn.png')
a = driver.page_source

print(a)

data_list = json.loads(a)
# Out:
# <!DOCTYPE html><html class="ks-webkit538 ks-webkit ks-safari2 ks-safari"><head><script type="text/javascript" async="" src="https://g.alicdn.com/alilog/oneplus/entry.js?t=210643"></script><script src="https://g.alicdn.com/aliww/web.ww/scripts/webww.js" async=""></script><script src="https://g.alicdn.com/kissy/k/1.3.0/waterfall-min.js?t=20130701201313" async="" charset="utf-8"></script><script src="https://g.alicdn.com/tbc/umpp/1.5.4/index-min.js?t=20130701201313" async="" charset="utf-8"></script><script type="text/javascript" async="" charset="utf-8" src="https://c.cnzz.com/core.php?web_id=30058275&amp;t=q"></script><script src="https://g.alicdn.com/mtb/app-idle-pc/1.7.7/widget/footer5/index-min.js?t=20130701201313" async="" charset="utf-8"></script><script type="text/javascript" async="" charset="utf-8" src="https://c.cnzz.com/core.php?web_id=1252911424&amp;t=q"></script><script src="https://g.alicdn.com/kissy/k/1.3.0/suggest-min.js?t=20130701201313" async="" charset="utf-8"></scri
# ...

# %%
#driver.quit()
