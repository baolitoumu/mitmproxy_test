# %%
# !mitmdump -p 8080
# Out:
# Proxy server listening at http://*:8080
# 127.0.0.1:54880: clientconnect
# 127.0.0.1:54880: CONNECT www.iplocation.net:443
#  << Cannot establish TLS with client (sni: www.iplocation.net): TlsException("(104, 'ECONNRESET')",)
# 127.0.0.1:54880: clientdisconnect
# 127.0.0.1:54990: clientconnect
# 127.0.0.1:54994: clientconnect
# 127.0.0.1:54996: clientconnect
# 127.0.0.1:54990: GET https://www.gstatic.com/chrome/intelligence/assist/ranker/models/translate/2017/03/translate_ranker_model_20170329.pb.bin HTTP/2.0
#               << 200  1.56k
# 127.0.0.1:54994: CONNECT www.iplocation.net:443
#  << Cannot establish TLS with client (sni: www.iplocation.net): TlsException("(-1, 'Unexpected EOF')",)
# 127.0.0.1:54994: clientdisconnect
# 127.0.0.1:54996: GET https://www.iplocation.net/ HTTP/2.0
#               << 200  8.73k
# 127.0.0.1:54998: clientconnect
# 127.0.0.1:54996: GET https://www.iplocation.net/assets/css/normalize.css HTTP/2.0
#               << 200  900b
# ...
