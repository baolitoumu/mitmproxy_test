# %%
 
import pymysql

# %%
# 打开数据库连接  


MYSQL_PORT = 3306               #数据库端口，在dbhelper中使用
db = pymysql.connect("localhost","root","shashuai","scrapy_db",charset="utf8" )

# %%
# 使用cursor()方法获取操作游标   
cursor = db.cursor()  
# SQL 插入语句

# %%
sql="insert into testtable(city_code,city_name,city_name_province,city_url,currPage,district,district_url,ershou,ershouCount,final_url,firstlevel_title,firstlevel_url,idleCount,item_From,item_FromDesc,item_FromTarget,item_Url,item_collectCount,item_commentCount,item_commentUrl,item_describe,item_imageHeight,item_imageUrl,item_imageWidth,item_isBrandNew,item_orgPrice,item_price,item_provcity,item_publishTime,item_title,numFound,threelevel,threelevel_url,totalPage,twolevel,twolevel_url,user_CreditUrl,user_Icon,user_ItemsUrl,user_Nick,user_TypeId,user_isSinaV,user_isTaobaoWomen,user_taobaoWomenUrl,user_vipLevel,user_yellowSeller,word) values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"  

item = {'city_code': '340300',
 'city_name': '蚌埠',
 'city_name_province': '安徽',
 'city_url': 'https://s.2.taobao.com/list/list.htm?_input_charset=utf8&q=代购&divisionId=340300',
 'currPage': 1,
 'district': '禹会区',
 'district_url': 'https://s.2.taobao.com/list/list.htm?catid=57548003&divisionId=340304&st_trust=1&q=%B4%FA%B9%BA&ist=1',
 'ershou': [],
 'ershouCount': 0,
 'final_url': 'https://s.2.taobao.com/list/waterfall/waterfall.htm?wp=1&_ksTS=1515549364328_483&stype=1&catid=57548003&divisionId=340304&st_trust=1&q=%B4%FA%B9%BA&ist=1',
 'firstlevel_title': '摩托车/用品',
 'firstlevel_url': 'https://s.2.taobao.com/list/list.htm?catid=57548003&divisionId=340300&st_trust=1&q=%B4%FA%B9%BA&ist=1',
 'idleCount': 1,
 'item_From': '发布自iPhone客户端',
 'item_FromDesc': 'iPhone客户端',
 'item_FromTarget': '//2.taobao.com/mobile/iphone.htm',
 'item_Url': '//2.taobao.com/item.htm?id=537936256860&amp;from=list&amp;similarUrl=',
 'item_collectCount': 0,
 'item_commentCount': 0,
 'item_commentUrl': '//2.taobao.com/item.htm?id=537936256860&amp;from=list&amp;similarUrl=#item-comments',
 'item_describe': '着地过几次，不超过2公里。前轮充气胎，后轮是橡胶胎。朋友送的，美国代购的。小孩小也不能玩。有意者私聊。拍下不退不换。见谅！',
 'item_imageHeight': 1334,
 'item_imageUrl': '//img.alicdn.com/bao/uploaded/i2/TB1ZxtoNXXXXXc4XFXXraWCFXXX_220x10000.jpg',
 'item_imageWidth': 750,
 'item_isBrandNew': False,
 'item_orgPrice': '',
 'item_price': '1600.00',
 'item_provcity': '安徽蚌埠',
 'item_publishTime': '2018.04.10',
 'item_title': 'Raozor/雷热 E100美国代购的 儿童踏板电动车',
 'numFound': 1,
 'threelevel': 0,
 'threelevel_url': 0,
 'totalPage': 1,
 'twolevel': 0,
 'twolevel_url': 0,
 'user_CreditUrl': '//s.2.taobao.com/list/list.htm?usernick=%B2%A9%D1%C5%CC%C3888',
 'user_Icon': '//wwc.alicdn.com/avatar/getAvatar.do?userNick=博雅堂888&width=30&height=30&type=sns',
 'user_ItemsUrl': '//s.2.taobao.com/list/list.htm?usernick=%B2%A9%D1%C5%CC%C3888',
 'user_Nick': '博雅堂888',
 'user_TypeId': [],
 'user_isSinaV': False,
 'user_isTaobaoWomen': False,
 'user_taobaoWomenUrl': '//mm.taobao.com/63390789.htm',
 'user_vipLevel': 3,
 'user_yellowSeller': False,
 'word': '代购'}    
if len(item['ershou']):
    print('ok')
else:
    item['ershou']=0
if len(item['user_TypeId']):
    print('ok')
else:
    item['user_TypeId'] =0
params = (
           item['city_code'],
 item['city_name'],
item['city_name_province'],
 item['city_url'],
  item['currPage'],
  item['district'],
  item['district_url'],
  item['ershou'],
  item['ershouCount'],
  item['final_url'],
  item['firstlevel_title'],
  item['firstlevel_url'],
  item['idleCount'],
  item['item_From'],
 item[ 'item_FromDesc'],
 item[ 'item_FromTarget'],
  item['item_Url'],
  item['item_collectCount'],
 item[ 'item_commentCount'],
  item['item_commentUrl'],
  item['item_describe'],
  item['item_imageHeight'],
  item['item_imageUrl'],
  item['item_imageWidth'],
  item['item_isBrandNew'],
  item['item_orgPrice'],
  item['item_price'],
  item['item_provcity'],
  item['item_publishTime'],
  item['item_title'],
  item['numFound'],
  item['threelevel'],
  item['threelevel_url'],
  item['totalPage'],
  item['twolevel'],
  item['twolevel_url'],
  item['user_CreditUrl'],
  item['user_Icon'],
  item['user_ItemsUrl'],
  item['user_Nick'],
  item['user_TypeId'],
  item['user_isSinaV'],
  item['user_isTaobaoWomen'],
  item['user_taobaoWomenUrl'],
  item['user_vipLevel'],
  item['user_yellowSeller'],
  item['word']
        )
print(type(item['ershou']))
print(sql)

try:  
   # 执行sql语句  
    cursor.execute(sql,params)

   # 执行sql语句  
    db.commit()  
    print("insert ok")  
except pymysql.Warning as w:
        ope.commit()
        print (repr(w))
        db.rollback()  

# 关闭数据库连接  
db.close()
# Out:
# <class 'int'>
# insert into testtable(city_code,city_name,city_name_province,city_url,currPage,district,district_url,ershou,ershouCount,final_url,firstlevel_title,firstlevel_url,idleCount,item_From,item_FromDesc,item_FromTarget,item_Url,item_collectCount,item_commentCount,item_commentUrl,item_describe,item_imageHeight,item_imageUrl,item_imageWidth,item_isBrandNew,item_orgPrice,item_price,item_provcity,item_publishTime,item_title,numFound,threelevel,threelevel_url,totalPage,twolevel,twolevel_url,user_CreditUrl,user_Icon,user_ItemsUrl,user_Nick,user_TypeId,user_isSinaV,user_isTaobaoWomen,user_taobaoWomenUrl,user_vipLevel,user_yellowSeller,word) values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# insert ok
